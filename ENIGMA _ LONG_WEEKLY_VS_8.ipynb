# %% [markdown]
# LONG WEEKLY ANALYSIS VS.8

# %%
import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import io
import numpy as np
import PySimpleGUI as sg
import xlwt
from xlwt.Workbook import *
from pandas import ExcelWriter
import xlsxwriter
import pandas_ta as ta

# %% [markdown]
# # IMPORTING WEEKLY DATABASE

# %%
BTC_Data_Folder = 'c:/Enigma/DataBase/BTS/'

# %%
wdb_mdb_ref = pd.DataFrame()

# %%
wdb_mdb_ref = pd.read_csv(BTC_Data_Folder+'wdb_mdb_ref.csv')
wdb_mdb_ref
# Out:
#                  Ref Name        Date       Open       High        Low  \
# 0      AAL2010-01-15  AAL  2010-01-15   5.130000   5.840000   4.940000
# 1      AAL2010-01-22  AAL  2010-01-22   5.500000   5.960000   5.110000
# 2      AAL2010-01-29  AAL  2010-01-29   5.340000   5.610000   4.470000
# 3      AAL2010-02-05  AAL  2010-02-05   5.430000   6.030000   5.350000
# 4      AAL2010-02-12  AAL  2010-02-12   5.880000   6.910000   5.820000
# ...              ...  ...         ...        ...        ...        ...
# 60075  WFC2022-02-18  WFC  2022-02-18  58.509998  59.320000  55.369999
# 60076  WFC2022-02-25  WFC  2022-02-25  55.570000  56.119999  50.680000
# 60077  WFC2022-03-04  WFC  2022-03-04  52.630001  53.400002  48.180000
# 60078  WFC2022-03-11  WFC  2022-03-11  48.580002  50.000000  45.770000
# 60079  WFC2022-03-14  WFC  2022-03-14  49.669998  50.061501  49.450001
#
#            Close  Adj_Close     Volume  M_IN
# 0       5.500000   5.185078   58976100   0.0
# ...

# %% [markdown]
# # WEEKLY BUY ARGUMENTS

# %%
wdb_mdb_ref['#'] = wdb_mdb_ref.groupby(wdb_mdb_ref['Name']).cumcount()+1

# %%
xw = wdb_mdb_ref['#'].max()
x=xw/4

# %%
WeeklyTestPath = 'c:/Enigma/Weekly/Test_Files/'

# %% [markdown]
# ## Weekly Panel

# %%
sg.theme('LightGreen6')   # Add a touch of color



# All the stuff inside your window.
layout = [  [sg.Text('WEEKLY SET-UP')],
            [sg.Text('________________')],
            [sg.Text('BUY ARGUMENTS')],
            [sg.Text('________________')],
            [sg.Text('W.Monthly_IN'), sg.Checkbox('',default=True)],
            [sg.Text('W.Volume_EMA3'), sg.Checkbox('',default=False)],
            [sg.Text('W.Volume_VAR_%'), sg.Input()],
            [sg.Text('W.Candle'), sg.Checkbox('', default=False)],
            [sg.Text('W.MA_Lined'), sg.Checkbox('', default=False)],
            [sg.Text('W.Above_MA20'), sg.Checkbox('', default=False)],
            [sg.Text('W.MA20_Crossed'), sg.Checkbox('', default=True)],
            [sg.Text('W.EMA8'), sg.Checkbox('', default=True)],
            [sg.Text('W.EMA3'), sg.Checkbox('', default=True)],
            [sg.Text('W.Sequince'), sg.Checkbox('', default=False)],
            [sg.Text('W.Trend'), sg.Checkbox('', default=False)],
            [sg.Text('W.Trend_VAR_%'), sg.Input() ],
            [sg.Text('____________________________')],
            [sg.Text('WEEKLY SELL ARGUMENTS')],
            [sg.Text('____________________________')],
            [sg.Text('W.Sell_JOKER'), sg.Checkbox('', default=True)],
            [sg.Text('W.Sell_EMA3'), sg.Checkbox('', default=False)],
            [sg.Text('W.EMA3_Sell_Above_%'), sg.Input() ],
            [sg.Text('W.VOL>EMA3'), sg.Checkbox('', default=False)],
            [sg.Text('W.VOL_EMA3_Sell_Above_%'), sg.Input() ],
            [sg.Text('W.JOKER_EMA'), sg.Input(35) ],

            [sg.Button('Run')] ]

# Create the Window
w_window = sg.Window('Enigma Weekly Panel', layout)
# Event Loop to process "events" and get the "values" of the inputs
while True:
    event, values = w_window.read()
    if event == sg.WIN_CLOSED or event == 'Run': # if user closes window or clicks cancel
        break
    x= values[0]

w_window.close()

# %%
if values[0] is True:
    W_Monthly_IN_exe = 1
else:
    W_Monthly_IN_exe = 0
    

if values[1] is True:
    W_Vol_EMA3_exe = 1
else:
    W_Vol_EMA3_exe = 0
    
W_Above_VOL_exe = values[2]

 
if values[3] is True:
    W_Candle_exe = 1
else:
    W_Candle_exe = 0
    
    
    
if values[4] is True:
    W_MA_Lined_exe = 1
else:
    W_MA_Lined_exe = 0
    

if values[5] is True:
    W_Above_MA20_exe = 1
else:
    W_Above_MA20_exe = 0
    
    
    
if values[6] is True:
    W_MA20_Crossed_exe = 1
else:
    W_MA20_Crossed_exe = 0
    
    

if values[7] is True:
    W_EMA8_exe = 1
else:
    W_EMA8_exe = 0
   
if values[8] is True:
    W_EMA3_exe = 1
else:
    W_EMA3_exe = 0
   
 
if values[9] is True:
    W_Sequince_exe = 1
else:
    W_Sequince_exe = 0    
    
    
    
if values[10] is True:
    W_Trend_exe = 1
else:
    W_Trend_exe = 0  
    
    
W_Trend_GAP_exe = values[11]

if W_Above_VOL_exe !='':
    W_Above_VOL_exe = int(W_Above_VOL_exe)/100
else:
    W_Above_VOL_exe=0
        
if W_Trend_GAP_exe !='':
    W_Trend_GAP_exe = int(W_Trend_GAP_exe)/100
else:
    W_Trend_GAP_exe=0
    
if values[12] is True:
    W_Sell_EMA8_exe = 1
else:
    W_Sell_EMA8_exe = 0     
    
if values[13] is True:
    W_Sell_EMA3_exe = 1
else:
    W_Sell_EMA3_exe = 0     
    
    
W_EMA_Sell_Above_exe = values[14]
    
if W_EMA_Sell_Above_exe !='':
    W_EMA_Sell_Above_exe = int(W_EMA_Sell_Above_exe)/100
else:
    W_EMA_Sell_Above_exe=0
    
    
    
if values[15] is True:
    W_VOL_EMA3_exe = 1
else:
    W_VOL_EMA3_exe = 0     
        
    
    
    
    
W_VOL_EMA3_Sell_Above  = values[16]
    
if W_VOL_EMA3_Sell_Above !='':
    W_VOL_EMA3_Sell_Above = int(W_VOL_EMA3_Sell_Above)/100
else:
    W_VOL_EMA3_Sell_Above = 0

# %%
W_PANEL = pd.DataFrame([['W_Monthly_IN',W_Monthly_IN_exe, ''],['W_VOL_EMA3',W_Vol_EMA3_exe, ''], ['W_VOL_VAR%',W_Above_VOL_exe, ''], 
                      ['W_Candle',W_Candle_exe, ''], ['W_MA_Lined',W_MA_Lined_exe, ''] ,['W_Above_MA20',W_Above_MA20_exe, ''] ,
                      ['W_MA20_Crossed',W_MA20_Crossed_exe, ''] ,['W_EMA8',W_EMA8_exe, ''],['W_EMA3',W_EMA3_exe, ''] ,['W_Sequince',W_Sequince_exe, ''] ,
                      ['W_Trend',W_Trend_exe, ''],['W_Trend_VAR_%',W_Trend_GAP_exe, ''],['W_EMA_JOKER_Sell_','', W_Sell_EMA8_exe],['W_EMA3_Sell_','', W_Sell_EMA3_exe],['W_EMA3_Sell_Above_%','', W_EMA_Sell_Above_exe],['W_VOL_Sell','', W_VOL_EMA3_exe], ['W_Vol_EMA3_Sell_Above_%','', W_VOL_EMA3_Sell_Above],['EMA_JOKER','', values[17] ]], columns=['ARGUMENTS','WEEKLY-BUY', 'WEEKLY-SELL'])


W_PANEL
# Out:
#                   ARGUMENTS WEEKLY-BUY WEEKLY-SELL
# 0              W_Monthly_IN          1
# 1                W_VOL_EMA3          0
# 2                W_VOL_VAR%          0
# 3                  W_Candle          0
# 4                W_MA_Lined          0
# 5              W_Above_MA20          0
# 6            W_MA20_Crossed          1
# 7                    W_EMA8          1
# 8                    W_EMA3          1
# 9                W_Sequince          0
# 10                  W_Trend          0
# 11            W_Trend_VAR_%          0
# 12        W_EMA_JOKER_Sell_                      1
# 13             W_EMA3_Sell_                      0
# 14      W_EMA3_Sell_Above_%                      0
# 15               W_VOL_Sell                      0
# 16  W_Vol_EMA3_Sell_Above_%                      0
# 17                EMA_JOKER                      8

# %%
### MONTHLY IN ARGUMENT ###

# %%
#wdb_mdb_ref["M_IN_Ref"] = 0
#wdb_mdb_ref["M_IN"] = 0

# %%
#count = 0
    
#while count < x:
    
        
     #wdb_mdb_ref.loc[(wdb_mdb_ref['#']==1), 'M_IN_Ref'] = 0
     #wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['Symbol_Pos']=="BUY"), 'M_IN_Ref'] ='BUY' 
     #wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['Symbol_Pos']=="HOLD"), 'M_IN_Ref'] ='HOLD' 
     #wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['Symbol_Pos']=="SELL"), 'M_IN_Ref'] ='SELL' 
    # wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['Symbol_Pos']=="OUT"), 'M_IN_Ref'] ='OUT' 
    # wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['Symbol_Pos']!="BUY")&(wdb_mdb_ref['Symbol_Pos']!="HOLD")&(wdb_mdb_ref['Symbol_Pos']!="SELL")&(wdb_mdb_ref['Symbol_Pos']!="OUT"), 'M_IN_Ref'] =wdb_mdb_ref["M_IN_Ref"].shift(1)
    # count = count + 1

# %% [markdown]
# ## Weekly Monthly IN

# %%
if W_Monthly_IN_exe==0:
    
    wdb_mdb_ref["M_IN"]=0
    
#else:
    



    #count = 0
    
    #while count < x:
    
        
      #   wdb_mdb_ref.loc[(wdb_mdb_ref['#']==1), 'M_IN'] = 0
      #   wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['M_IN_Ref']=="BUY"), 'M_IN'] =1 
       #  wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['M_IN_Ref']=="HOLD"), 'M_IN'] =1 
       #  wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['M_IN_Ref']=="SELL"), 'M_IN'] =0
        # wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['M_IN_Ref']=="OUT"), 'M_IN'] =0
        # wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['M_IN_Ref']!="BUY")&(wdb_mdb_ref['M_IN_Ref']!="HOLD")&(wdb_mdb_ref['M_IN_Ref']!="SELL")&(wdb_mdb_ref['M_IN_Ref']!="OUT"), 'M_IN'] =wdb_mdb_ref["M_IN"].shift(1)
     
       #  count = count + 1

# %% [markdown]
# ### Weekly Monthly In Test

# %%
# M_IN Test File (for weekly results)

wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_Monthly_in_TST.csv', columns=('#','Name','Date','Close','M_IN'))

# %% [markdown]
# ## Weekly Candle Argument

# %%
wdb_mdb_ref["Candle"] = 0

# %%
# Define Green / Red Candle Argument#
#Green =1, Red =0#


if W_Candle_exe==0:
    
    wdb_mdb_ref["Candle"]=0
    
else:
    
    wdb_mdb_ref["Candle"] = np.where(wdb_mdb_ref["Open"] < wdb_mdb_ref["Close"], 1, 0)

# %% [markdown]
# ### Candle Argument Test

# %%
# Candle Test File

wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_CandleTST.csv', columns=('Name','Date','Open','Close','Candle'),index=False)

# %%
### WEEKLY CANDLE ARGUMENT END ###

# %% [markdown]
# ## Weekly Volume Arguments

# %% [markdown]
# ### Weekly Avg Vol

# %%
# AVG Weekly VOLUME START #

wdb_mdb_ref['Accu_Vol'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Volume.cumsum()
wdb_mdb_ref['Avg_Vol'] = wdb_mdb_ref['Accu_Vol'] / wdb_mdb_ref["#"]

# AVG VOLUME END #

# %% [markdown]
# ### Weekly EMA3 Vol

# %%
# EMA3 / EMA8 Weekly VOLUME START #

#Weekly_Vol_EMA3#

###Calc Weekly VOL_MA_3###

wdb_mdb_ref["VOL_MA3"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Volume.transform(lambda c: c.rolling(3).mean())
wdb_mdb_ref["VOL_MA3"] = wdb_mdb_ref["VOL_MA3"].fillna(0)

###Calc Weekly VOL EMA_3###

wdb_mdb_ref.loc[(wdb_mdb_ref['#']<3), 'Vol_EMA3'] =  0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']==3), 'Vol_EMA3'] =  wdb_mdb_ref["Avg_Vol"]
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>3), 'Vol_EMA3'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Volume.transform(lambda c: c.ewm(span=3, adjust=False).mean())
    


#count = 0
    
#while count < xw:
  #  wdb_mdb_ref.loc[(wdb_mdb_ref['#']<3), 'Vol_EMA3'] = 0
  #  wdb_mdb_ref.loc[(wdb_mdb_ref['#']==3), 'Vol_EMA3'] = wdb_mdb_ref["VOL_MA3"]
   # wdb_mdb_ref.loc[(wdb_mdb_ref['#']>3), 'Vol_EMA3'] = ((wdb_mdb_ref["Volume"]*0.5)+(wdb_mdb_ref["Vol_EMA3"].shift(1)*(0.5)))
        
#    count = count + 1

# %% [markdown]
# ### Weekly EMA8 Vol

# %%
#Weekly Vol_EMA8

###Calc Weekly VOL MA_8###
wdb_mdb_ref["VOL_MA8"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Volume.transform(lambda c: c.rolling(8).mean())
wdb_mdb_ref["VOL_MA8"] = wdb_mdb_ref["VOL_MA8"].fillna(0)

###Calc Weekly VOL EMA_8###

wdb_mdb_ref.loc[(wdb_mdb_ref['#']<8), 'Vol_EMA8'] =  0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']==8), 'Vol_EMA8'] =  wdb_mdb_ref["Avg_Vol"]
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>8), 'Vol_EMA8'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Volume.transform(lambda c: c.ewm(span=8, adjust=False).mean())
    






#count = 0
    
#while count < xw:
    
  #  wdb_mdb_ref.loc[(wdb_mdb_ref['#']<8), 'Vol_EMA8'] = 0
  #  wdb_mdb_ref.loc[(wdb_mdb_ref['#']==8), 'Vol_EMA8'] = wdb_mdb_ref["VOL_MA8"]
 #   wdb_mdb_ref.loc[(wdb_mdb_ref['#']>8), 'Vol_EMA8'] = (wdb_mdb_ref["Volume"]*(2/9))+(wdb_mdb_ref["Vol_EMA8"].shift(1)*(1-(2/9)))
        
#    count = count + 1

# %% [markdown]
# ### Weekly Vol VAR

# %%
 # Weekly Vol.Arguments# 

wdb_mdb_ref['Vol_Avg_ARG']=0
wdb_mdb_ref['Vol_EMA3_ARG']=0
wdb_mdb_ref['Vol_EMA8_ARG']=0


#more then Above_Vol_Exe#

wdb_mdb_ref.loc[(wdb_mdb_ref['#']==1), 'Vol_Avg_ARG'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['Volume']*(1+W_Above_VOL_exe)>=wdb_mdb_ref['Avg_Vol']),'Vol_Avg_ARG']= 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']!=1)&(wdb_mdb_ref['Volume']*(1+W_Above_VOL_exe)<wdb_mdb_ref['Avg_Vol']),'Vol_Avg_ARG'] = 0

if W_Vol_EMA3_exe==0:
    wdb_mdb_ref['Vol_EMA3_ARG']=0
else:
    wdb_mdb_ref.loc[(wdb_mdb_ref['#']<3), 'Vol_EMA3_ARG'] = 0
    wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=3)&((wdb_mdb_ref['Volume']*(1+W_Above_VOL_exe))>=wdb_mdb_ref['Vol_EMA3']), 'Vol_EMA3_ARG'] = 1
    wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=3)&((wdb_mdb_ref['Volume']*(1+W_Above_VOL_exe))<wdb_mdb_ref['Vol_EMA3']), 'Vol_EMA3_ARG'] = 0
    
    
    
wdb_mdb_ref.loc[(wdb_mdb_ref['#']<8), 'Vol_EMA8_ARG'] = 0    
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=8)&((wdb_mdb_ref['Volume']*(1+W_Above_VOL_exe))>=wdb_mdb_ref['Vol_EMA8']), 'Vol_EMA8_ARG'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=8)&((wdb_mdb_ref['Volume']*(1+W_Above_VOL_exe))<wdb_mdb_ref['Vol_EMA8']), 'Vol_EMA8_ARG'] = 0

# %% [markdown]
# ### Weekly Volume Test

# %%
wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_Volume_TST.csv', columns=('#', 'Name','Date','Volume','Accu_Vol','Avg_Vol','VOL_MA3','VOL_MA8','Vol_EMA3','Vol_EMA8', 'Vol_Avg_ARG','Vol_EMA3_ARG', 'Vol_EMA8_ARG'  ),index=False)

# %% [markdown]
# ## Weekly Moving AVG & EMA (on Close Price)

# %% [markdown]
# ### Weekly Moving AVG 20 / 50 / 200 / 3 / 5 / 8

# %%
### Calculating Weekly MA20 / MA50 / MA200 ###


wdb_mdb_ref["CLS_MA20"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.rolling(20).mean())
wdb_mdb_ref["CLS_MA20"] = wdb_mdb_ref["CLS_MA20"].fillna(0)

wdb_mdb_ref["CLS_MA50"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.rolling(50).mean())
wdb_mdb_ref["CLS_MA50"] = wdb_mdb_ref["CLS_MA50"].fillna(0)

wdb_mdb_ref["CLS_MA200"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.rolling(200).mean())
wdb_mdb_ref["CLS_MA200"] = wdb_mdb_ref["CLS_MA200"].fillna(0)

# %%
wdb_mdb_ref["CLS_MA3"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.rolling(3).mean())
wdb_mdb_ref["CLS_MA3"] = wdb_mdb_ref["CLS_MA3"].fillna(0)

# %%
wdb_mdb_ref["CLS_MA5"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.rolling(5).mean())
wdb_mdb_ref["CLS_MA5"] = wdb_mdb_ref["CLS_MA5"].fillna(0)

# %%
wdb_mdb_ref["CLS_MA8"] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.rolling(8).mean())
wdb_mdb_ref["CLS_MA8"] = wdb_mdb_ref["CLS_MA8"].fillna(0)

# %% [markdown]
# ### Weekly E_Moving AVG  3 / 5 / 8

# %%
### Calculating Weekly EMA3 / EMA5 / EMA8 ###


###Calc Weekly EMA_3###


wdb_mdb_ref.loc[(wdb_mdb_ref['#']<3), 'CLS_EMA3'] =  0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']==3), 'CLS_EMA3'] =  wdb_mdb_ref["CLS_MA3"]
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>3), 'CLS_EMA3'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.ewm(span=3, adjust=False).mean())
    


###Calc EMA_5###

wdb_mdb_ref.loc[(wdb_mdb_ref['#']<5), 'CLS_EMA5'] =  0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']==5), 'CLS_EMA5'] =  wdb_mdb_ref["CLS_MA5"]
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>5), 'CLS_EMA5'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.ewm(span=5, adjust=False).mean())
    

###Calc Weekly EMA_8###


wdb_mdb_ref.loc[(wdb_mdb_ref['#']<8), 'CLS_EMA8'] =  0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']==8), 'CLS_EMA8'] =  wdb_mdb_ref["CLS_MA8"]
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>8), 'CLS_EMA8'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.ewm(span=8, adjust=False).mean())

# %% [markdown]
# ### Weekly Moving AVG & EMA Test File

# %%
# WEEKLY Moving AVG, EMA (on Close Price) - TEST FILE

wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_CLS_EMA_MA_TEST.csv', columns=('#','Name','Date','Open','Close','CLS_MA20','CLS_MA50','CLS_MA200','CLS_MA3','CLS_MA5','CLS_MA8','CLS_EMA3','CLS_EMA5','CLS_EMA8'),index=False)

# %%
###Moving AVG, EMA (on Close Price) End###

# %% [markdown]
# ## Weekly MA-LINED

# %%
#WEEKLY - MA LINED#

wdb_mdb_ref["MA_LINED"]=0


if W_MA_Lined_exe==0:
    wdb_mdb_ref["MA_LINED"]=0
    
else:
    wdb_mdb_ref.loc[(wdb_mdb_ref['CLS_MA20']>wdb_mdb_ref['CLS_MA50'])&(wdb_mdb_ref['CLS_MA50']>wdb_mdb_ref['CLS_MA200']), 'MA_LINED'] = 1
    wdb_mdb_ref.loc[(wdb_mdb_ref['CLS_MA20']>wdb_mdb_ref['CLS_MA50'])&(wdb_mdb_ref['CLS_MA200']==0), 'MA_LINED'] = 1
    wdb_mdb_ref.loc[(wdb_mdb_ref['CLS_MA20']<=wdb_mdb_ref['CLS_MA50']), 'MA_LINED'] = 0
    wdb_mdb_ref.loc[(wdb_mdb_ref['CLS_MA50']<=wdb_mdb_ref['CLS_MA200']), 'MA_LINED'] = 0

# %% [markdown]
# ### Weekly MA-LINED Test Files

# %%
#WEEKLY - MA LINED-TEST#
wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_MA_LINED_TST.csv', columns=('#', 'Name','Date','Close','CLS_MA20','CLS_MA50','CLS_MA200','MA_LINED' ),index=False)

# %% [markdown]
# ## Weekly Closing Price > MA20 / EMA3 / EMA8

# %%
#### CLS>MA20# #CLS>EMA8# #CLS>EMA3# WEEKLY START ####

# %%
#Close Above MA20

wdb_mdb_ref["CLS>MA20"]=0


    
wdb_mdb_ref.loc[(wdb_mdb_ref['#']<20), 'CLS>MA20'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=20)&(wdb_mdb_ref['Close']>wdb_mdb_ref['CLS_MA20']), 'CLS>MA20'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=20)&(wdb_mdb_ref['Close']<=wdb_mdb_ref['CLS_MA20']), 'CLS>MA20'] = 0

#Close Above EMA8

wdb_mdb_ref["CLS>EMA8"]=0


    
wdb_mdb_ref.loc[(wdb_mdb_ref['#']<8), 'CLS>EMA8'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=8)&(wdb_mdb_ref['Close']>wdb_mdb_ref['CLS_EMA8']), 'CLS>EMA8'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=8)&(wdb_mdb_ref['Close']<=wdb_mdb_ref['CLS_EMA8']), 'CLS>EMA8'] = 0

#Close Above EMA3


wdb_mdb_ref.loc[(wdb_mdb_ref['#']<3), 'CLS>EMA3'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=3)&(wdb_mdb_ref['Close']>wdb_mdb_ref['CLS_EMA3']), 'CLS>EMA3'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=3)&(wdb_mdb_ref['Close']<=wdb_mdb_ref['CLS_EMA3']), 'CLS>EMA3'] = 0


###JOKER SELL EMA###
J=int(values[17])


wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=J), 'CLS_EMAJ'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.ewm(span=J, adjust=False).mean())

    

wdb_mdb_ref.loc[(wdb_mdb_ref['#']<J), 'CLS>EMAJ'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=J)&(wdb_mdb_ref['Close']>wdb_mdb_ref['CLS_EMAJ']), 'CLS>EMAJ'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=J)&(wdb_mdb_ref['Close']<=wdb_mdb_ref['CLS_EMAJ']), 'CLS>EMAJ'] = 0

# %% [markdown]
# ### Closing Price > MA20 / EMA3 / EMA8  Test File

# %%
# CLS>MA20# #CLS>EMA8# #CLS>EMA3# TEST#

wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_EMA3&EMA8_TST.csv', columns=('#', 'Name','Date','Close','CLS_EMA3','CLS_EMA8','CLS_MA20','CLS>EMA3','CLS>EMA8','CLS>MA20' ),index=False)

# %% [markdown]
# ## Weekly Touch MA20

# %%
wdb_mdb_ref["touch"]=0

if W_MA20_Crossed_exe==0:
    wdb_mdb_ref["touch"]=0
    
else:
    wdb_mdb_ref.loc[(wdb_mdb_ref['High']>wdb_mdb_ref['CLS_MA20'])&(wdb_mdb_ref['Low']<wdb_mdb_ref['CLS_MA20']), 'touch'] = 1
    wdb_mdb_ref.loc[(wdb_mdb_ref['High']<=wdb_mdb_ref['CLS_MA20']), 'touch'] = 0
    wdb_mdb_ref.loc[(wdb_mdb_ref['Low']>=wdb_mdb_ref['CLS_MA20']), 'touch'] = 0

# %%
wdb_mdb_ref["touchma20_ref"]=0

if W_MA20_Crossed_exe==0:
    wdb_mdb_ref["touchma20_ref"]=0
    
else:
    
    count = 0

    while count < x:
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'touchma20_ref'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch']==1)&(wdb_mdb_ref['CLS>MA20']==0), 'touchma20_ref'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch']==1)&(wdb_mdb_ref['CLS>MA20']==1), 'touchma20_ref'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch']!=1)&(wdb_mdb_ref['CLS>MA20']==0), 'touchma20_ref'] = wdb_mdb_ref["touchma20_ref"].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch']!=1)&(wdb_mdb_ref['CLS>MA20']==1), 'touchma20_ref'] = 0

        count = count + 1

# %%
wdb_mdb_ref["MA20TOUCH"]=0


if W_MA20_Crossed_exe==0:
    wdb_mdb_ref["MA20TOUCH"]=0
    
else:

    count = 0

    while count < x:
        
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'MA20TOUCH'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS_EMA8'] == 1) & (wdb_mdb_ref['touchma20_ref'] == 0) & (wdb_mdb_ref['touchma20_ref'].shift(1) == 1), 'MA20TOUCH'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS_EMA8'] == 1) & (wdb_mdb_ref['touchma20_ref'] == 0) & (wdb_mdb_ref['touchma20_ref'].shift(1) != 1), 'MA20TOUCH'] = wdb_mdb_ref["MA20TOUCH"].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS_EMA8'] == 1) & (wdb_mdb_ref['touchma20_ref'] != 0) , 'MA20TOUCH'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS_EMA8'] != 1)  , 'MA20TOUCH'] = 0
    
        count = count + 1

# %%
W_Above_MA20_exe
# Out:
# 0

# %% [raw]
# wdb_mdb_ref["touch&ema8"]=0
#
# if W_MA20_Crossed_exe==0:
#     wdb_mdb_ref["touch&ema8"]=0
#
# else:
#
#     count = 0
#
#     while count < x:
#
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'touch&ema8'] = 0
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8'] ==0) & (wdb_mdb_ref['touch'] == 1), 'touch&ema8'] = 1
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8'] ==1) & (wdb_mdb_ref['touch'] == 1), 'touch&ema8'] = 0
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8'] ==1) & (wdb_mdb_ref['touch'] == 0), 'touch&ema8'] = 0
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8'] ==0) & (wdb_mdb_ref['touch'] == 0), 'touch&ema8'] = wdb_mdb_ref['touch&ema8'].shift(1)
#
#         count = count + 1

# %% [raw]
# wdb_mdb_ref["touch8new"]=0
#
# if W_MA20_Crossed_exe==0:
#     wdb_mdb_ref["touch8new"]=0
#
# else:
#
#
#     count = 0
#
#     while count < x:
#
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'touch8new'] = 0
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch&ema8'] == 1), 'touch8new'] = 1
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8'] ==1) & (wdb_mdb_ref['touch&ema8'] == 0), 'touch8new'] = 1
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8'] ==0) & (wdb_mdb_ref['touch&ema8'] == 0), 'touch8new'] = 0
#
#
#         count = count + 1

# %% [raw]
# wdb_mdb_ref["MA20TOUCH"]=0
#
#
# if W_MA20_Crossed_exe==0:
#     wdb_mdb_ref["MA20TOUCH"]=0
#
# else:
#
#     count = 0
#
#     while count < x:
#
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'MA20TOUCH'] = 0
#
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch'] == 1), 'MA20TOUCH'] = 1
#
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch'] != 1)&(wdb_mdb_ref['touch8new'] == 1), 'MA20TOUCH'] = wdb_mdb_ref['MA20TOUCH'].shift(1)
#
#         wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['touch8new'] != 1) & (wdb_mdb_ref['touch8new'] != 1), 'MA20TOUCH'] = 0
#
#         count = count + 1

# %% [markdown]
# ### Weekly Touch MA20 Test File

# %%
wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_TouchMA20_TST.csv', columns=('#', 'Name','Date','High','Low','Close','CLS_MA20','touch','CLS>EMA8','CLS>MA20','touchma20_ref','MA20TOUCH' ),index=False)

# %% [markdown]
# ## Weekly Sequense

# %%
 wdb_mdb_ref["seq_up"] = ""
 wdb_mdb_ref["seq_dw"] = ""
 wdb_mdb_ref["SEQ_UP/DOWN"] = ""
 wdb_mdb_ref["seq_ref_up"] = ""
 wdb_mdb_ref["seq_ref_dw"] = ""
 wdb_mdb_ref["seq_ref_y/n"] = ""
 wdb_mdb_ref["seq_open"] = 0
 wdb_mdb_ref["seq_high"] = 0
 wdb_mdb_ref["seq_low"] = 0
 wdb_mdb_ref["seq_close"] = 0
 wdb_mdb_ref["seq_adj_close"] = 0

# %%
if W_Sequince_exe==0:
    
    wdb_mdb_ref["seq_up"] = 0
    wdb_mdb_ref["seq_dw"] = 0
    wdb_mdb_ref["SEQ_UP/DOWN"] = 0
    wdb_mdb_ref["seq_ref_up"] = 0
    wdb_mdb_ref["seq_ref_dw"] = 0
    wdb_mdb_ref["seq_ref_y/n"] = 0
    wdb_mdb_ref["seq_open"] = 0
    wdb_mdb_ref["seq_high"] = 0
    wdb_mdb_ref["seq_low"] = 0
    wdb_mdb_ref["seq_close"] = 0
    wdb_mdb_ref["seq_adj_close"] = 0
    
else:

    count = 0

    while count < x:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_open'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] == 'y')&(wdb_mdb_ref['#'] != 1), 'seq_open'] = wdb_mdb_ref["Open"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] != 'y')&(wdb_mdb_ref['#'] != 1), 'seq_open'] = wdb_mdb_ref["seq_open"].shift(1)
    
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_high'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] == 'y')&(wdb_mdb_ref['#'] != 1), 'seq_high'] = wdb_mdb_ref["High"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] != 'y')&(wdb_mdb_ref['#'] != 1), 'seq_high'] = wdb_mdb_ref["seq_high"].shift(1)
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_low'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] == 'y')&(wdb_mdb_ref['#'] != 1), 'seq_low'] = wdb_mdb_ref["Low"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] != 'y')&(wdb_mdb_ref['#'] != 1), 'seq_low'] = wdb_mdb_ref["seq_low"].shift(1)
        
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_close'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] == 'y')&(wdb_mdb_ref['#'] != 1), 'seq_close'] = wdb_mdb_ref["Close"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] != 'y')&(wdb_mdb_ref['#'] != 1), 'seq_close'] = wdb_mdb_ref["seq_close"].shift(1)
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_adj_close'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] == 'y')&(wdb_mdb_ref['#'] != 1), 'seq_adj_close'] = wdb_mdb_ref["Adj_Close"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_y/n'] != 'y')&(wdb_mdb_ref['#'] != 1), 'seq_adj_close'] = wdb_mdb_ref["seq_adj_close"].shift(1)
    
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_up'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'].shift(1) == 'up')&(wdb_mdb_ref['Close']>wdb_mdb_ref['seq_low'].shift(1)) , 'seq_up'] = 'up'
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'].shift(1) == 'up')&(wdb_mdb_ref['Close']<=wdb_mdb_ref['seq_low'].shift(1)) , 'seq_up'] = '0'
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'].shift(1) !='up')&(wdb_mdb_ref['Close']>wdb_mdb_ref['seq_high'].shift(1)) , 'seq_up'] = 'up'
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'].shift(1) !='up')&(wdb_mdb_ref['Close']<=wdb_mdb_ref['seq_high'].shift(1)) , 'seq_up'] = '0'
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_dw'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'] =='up'), 'seq_dw'] = '0'
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'] !='up'), 'seq_dw'] = 'dw'
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'SEQ_UP/DOWN'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'] =='up'), 'SEQ_UP/DOWN'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_dw'] =='dw'), 'SEQ_UP/DOWN'] = 0
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_ref_up'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'] == 'up')&(wdb_mdb_ref['High']>wdb_mdb_ref['seq_high'].shift(1)) , 'seq_ref_up'] = 'ref_up'
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'] == 'up')&(wdb_mdb_ref['High']<=wdb_mdb_ref['seq_high'].shift(1)) , 'seq_ref_up'] = '0'
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_up'] != 'up'), 'seq_ref_up'] = '0'
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_ref_dw'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_dw'] == 'dw')&(wdb_mdb_ref['Low']<wdb_mdb_ref['seq_low'].shift(1)) , 'seq_ref_dw'] = 'ref_dw'
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_dw'] == 'dw')&(wdb_mdb_ref['Low']>=wdb_mdb_ref['seq_low'].shift(1)) , 'seq_ref_dw'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_dw'] != 'dw'), 'seq_ref_dw'] = '0'
    
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'seq_ref_y/n'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_up'] =='ref_up'), 'seq_ref_y/n'] = "y"
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_up'] !='ref_up')&(wdb_mdb_ref['seq_ref_dw'] =='ref_dw'), 'seq_ref_y/n'] = "y"
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['seq_ref_up'] !='ref_up')&(wdb_mdb_ref['seq_ref_dw'] !='ref_dw'), 'seq_ref_y/n'] = "n"
    

        

    
        count = count + 1

# %% [markdown]
# ### Weekly Sequense Test

# %%
#WEEKLY SEQUENSE TEST#

wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_SEQ_TST.csv', columns=('#', 'Name','Date','Open','High','Low','Close','Adj_Close','seq_ref_up','seq_ref_dw','seq_ref_y/n','seq_up','seq_dw','SEQ_UP/DOWN','seq_open','seq_high','seq_low','seq_close','seq_adj_close'  ),index=False)

# %% [markdown]
# ## Weekly Trend

# %%
wdb_mdb_ref["trendPTup"] = 0 
wdb_mdb_ref["trendMaxPTup"] = 0
wdb_mdb_ref["trendupref"] = 0
wdb_mdb_ref["2trdupmark"] = 0
wdb_mdb_ref["trendPTdw"] = 0
wdb_mdb_ref["trendMinPTdw"] = 0
wdb_mdb_ref["2trdDWmark"] = 0
wdb_mdb_ref["TrendCalc"] = 0       
wdb_mdb_ref["UP_DW_TREND"] = 0

# %%
#Trend Up Point#

if W_Trend_exe==0:
    
    wdb_mdb_ref["trendPTup"] = 0
    
else:
    
    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'trendPTup'] == 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['SEQ_UP/DOWN'] == 1)&(wdb_mdb_ref['Close'] > wdb_mdb_ref['trendPTup'].shift(1)), 'trendPTup'] = wdb_mdb_ref["Close"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['SEQ_UP/DOWN'] == 1)&(wdb_mdb_ref['Close'] <= wdb_mdb_ref['trendPTup'].shift(1)), 'trendPTup'] = wdb_mdb_ref['trendPTup'].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['SEQ_UP/DOWN'] != 1), 'trendPTup'] = 0
    
        count = count + 1

# %%
#Trend Up Max Point#

if W_Trend_exe==0:
    
    wdb_mdb_ref["trendMaxPTup"] = 0
    
else:

    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'trendMaxPTup'] == 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendPTup']== 0)&(wdb_mdb_ref['#'] != 1),'trendMaxPTup'] = wdb_mdb_ref["trendPTup"].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendPTup']!= 0)&(wdb_mdb_ref['#'] != 1),'trendMaxPTup'] = 0
    
        count = count + 1

# %%
#Trend Up Ref Point#

if W_Trend_exe==0:
    
    wdb_mdb_ref["trendupref"] = 0
    
else:

    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'trendupref'] == 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendMaxPTup']== 0)&(wdb_mdb_ref['#'] != 1),'trendupref'] = wdb_mdb_ref["trendupref"].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendMaxPTup']!= 0)&(wdb_mdb_ref['#'] != 1),'trendupref'] = wdb_mdb_ref['trendMaxPTup']
    
        count = count + 1

# %%
#2 Up trends Mark # ## TO ADD CHANGEABLE GAP

#ABOVE TREND_GAP_EXE#

if W_Trend_exe==0:
    
    wdb_mdb_ref["2trdupmark"] = 0
    
else:

    count = 0

    while count < xw/2:
        
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), '2trdupmark'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendMaxPTup'].shift(-1)>wdb_mdb_ref["trendupref"]*(1+W_Trend_GAP_exe))&(wdb_mdb_ref['#'] != 1),'2trdupmark'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendMaxPTup'].shift(-1)<=wdb_mdb_ref["trendupref"])&(wdb_mdb_ref['#'] != 1),'2trdupmark'] = 0

    
        count = count + 1

# %%
#Trend DW Point#

if W_Trend_exe==0:
    
    wdb_mdb_ref["trendPTdw"] = 0
    
else:

    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'trendPTdw'] == 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN'] == 0)&(wdb_mdb_ref['SEQ_UP/DOWN'].shift(1)==1), 'trendPTdw'] = wdb_mdb_ref["Close"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN'] == 0)&(wdb_mdb_ref['SEQ_UP/DOWN'].shift(1)!=1)&(wdb_mdb_ref["Close"]<wdb_mdb_ref["trendPTdw"].shift(1)), 'trendPTdw'] = wdb_mdb_ref["Close"]
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN'] == 0)&(wdb_mdb_ref['SEQ_UP/DOWN'].shift(1)!=1)&(wdb_mdb_ref["Close"]>=wdb_mdb_ref["trendPTdw"].shift(1)), 'trendPTdw'] = wdb_mdb_ref["trendPTdw"].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN'] != 0), 'trendPTdw'] = 0
    
        count = count + 1

# %%
#Trend DW Min Point#

if W_Trend_exe==0:
    
    wdb_mdb_ref["trendMinPTdw"] = 0
    
else:

    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'trendMinPTdw'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendPTdw']== 0)&(wdb_mdb_ref['#'] != 1),'trendMinPTdw'] = wdb_mdb_ref["trendPTdw"].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendPTdw']!= 0)&(wdb_mdb_ref['#'] != 1),'trendMinPTdw'] = 0
    
        count = count + 1

# %%
#Trend Dw Ref Point#

if W_Trend_exe==0:
    
    wdb_mdb_ref["trendDWref"] = 0
    
else:

    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'trendDWref'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendMinPTdw']== 0)&(wdb_mdb_ref['#'] != 1),'trendDWref'] = wdb_mdb_ref["trendDWref"].shift(1)
        wdb_mdb_ref.loc[(wdb_mdb_ref['trendMinPTdw']!= 0)&(wdb_mdb_ref['#'] != 1),'trendDWref'] = wdb_mdb_ref['trendMinPTdw']
    
        count = count + 1

# %%
#2 Dw trends Mark # ## TO ADD CHANGEABLE GAP

#ABOVE TREND_GAP_EXE#

if W_Trend_exe==0:
    
    wdb_mdb_ref["2trdDWmark"] = 0
    
else:

    count = 0

    while count < xw/2:
        
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), '2trdDWmark'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['trendMinPTdw'].shift(-1)>wdb_mdb_ref["trendDWref"]*(1+W_Trend_GAP_exe)),'2trdDWmark'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['trendMinPTdw'].shift(-1)<=wdb_mdb_ref["trendDWref"]),'2trdDWmark'] = 0
    
        count = count + 1

# %%
#TREND Calculation

if W_Trend_exe==0:
    
    wdb_mdb_ref["TrendCalc"] = 0
    
else:

    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'TrendCalc'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN']==0)&(wdb_mdb_ref["TrendCalc"].shift(1)==1),'TrendCalc'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN']==0)&(wdb_mdb_ref["TrendCalc"].shift(1)!=1)&(wdb_mdb_ref["2trdupmark"].shift(1)==1),'TrendCalc'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN']==0)&(wdb_mdb_ref["TrendCalc"].shift(1)!=1)&(wdb_mdb_ref["2trdupmark"].shift(1)!=1),'TrendCalc'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['SEQ_UP/DOWN']!=0),'TrendCalc'] = 0
    
        count = count + 1

# %%
#TREND DECITION
        
if W_Trend_exe==0:
    
    wdb_mdb_ref["UP_DW_TREND"] = 0
    
else:

    count = 0

    while count < xw/2:
       
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'UP_DW_TREND'] = 0
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['TrendCalc'].shift(1) + wdb_mdb_ref["2trdDWmark"].shift(1) == 2),'UP_DW_TREND'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['TrendCalc'].shift(1) + wdb_mdb_ref["2trdDWmark"].shift(1) != 2) & (wdb_mdb_ref["UP_DW_TREND"].shift(1)==1)& (wdb_mdb_ref['MA_LINED']==1) ,'UP_DW_TREND'] = 1
        wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['TrendCalc'].shift(1) + wdb_mdb_ref["2trdDWmark"].shift(1) != 2) & (wdb_mdb_ref["UP_DW_TREND"].shift(1)==1) & (wdb_mdb_ref['MA_LINED']!=1) ,'UP_DW_TREND'] = 0
    
        count = count + 1

# %% [markdown]
# ### Weekly Trend Test

# %%
#WEEKLY TREND TEST

wdb_mdb_ref.to_csv(WeeklyTestPath + 'W_TREND_TST.csv', columns=('#', 'Name','Date','Close','MA_LINED','SEQ_UP/DOWN','trendPTup','trendMaxPTup','trendupref','2trdupmark','trendPTdw','trendMinPTdw','trendDWref','2trdDWmark','TrendCalc','UP_DW_TREND'))

# %% [markdown]
# # WEEKLY BUY

# %%
#Creating WEEKLY Buy/Sell Path Testing Folders#
W_Buy_Sell_Path = 'c:/Enigma/Weekly/Buy_Sell/'

# %%
if W_Above_MA20_exe==0:
    wdb_mdb_ref["CLS>MA20"]=0
    
if W_EMA8_exe==0:
    wdb_mdb_ref["CLS>EMA8"]=0   

if W_EMA3_exe==0:
    wdb_mdb_ref['CLS>EMA3']=0

# %%
wdb_mdb_ref["Buy_Combined"] = 0
wdb_mdb_ref["BUY_Decision"] = 0
wdb_mdb_ref["Temp_BUY"] = 0

# %%
wdb_mdb_ref["Buy_Combined"] = wdb_mdb_ref['M_IN']+ wdb_mdb_ref['Vol_EMA3_ARG'] + wdb_mdb_ref['Candle']  + wdb_mdb_ref['MA_LINED']+wdb_mdb_ref['CLS>MA20']+ wdb_mdb_ref['CLS>EMA8']+ wdb_mdb_ref['CLS>EMA3'] + wdb_mdb_ref['MA20TOUCH'] + wdb_mdb_ref['SEQ_UP/DOWN'] + wdb_mdb_ref['UP_DW_TREND']

# %%
wdb_mdb_ref["BUY_Decision"] = W_Monthly_IN_exe+W_Vol_EMA3_exe + W_Candle_exe + W_MA_Lined_exe  + W_Above_MA20_exe + W_MA20_Crossed_exe + W_EMA8_exe+W_EMA3_exe + W_Sequince_exe + W_Trend_exe

# %%
wdb_mdb_ref.loc[(wdb_mdb_ref['Buy_Combined'] ==wdb_mdb_ref["BUY_Decision"]), 'Temp_BUY'] = 1

# %%
### ReCalc EMA8 & EMA3 ###

# %%
wdb_mdb_ref.loc[(wdb_mdb_ref['#']<8), 'CLS>EMA8'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=8)&(wdb_mdb_ref['Close']>wdb_mdb_ref['CLS_EMA8']), 'CLS>EMA8'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=8)&(wdb_mdb_ref['Close']<=wdb_mdb_ref['CLS_EMA8']), 'CLS>EMA8'] = 0


wdb_mdb_ref.loc[(wdb_mdb_ref['#']<3), 'CLS>EMA3'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=3)&(wdb_mdb_ref['Close']>wdb_mdb_ref['CLS_EMA3']), 'CLS>EMA3'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=3)&(wdb_mdb_ref['Close']<=wdb_mdb_ref['CLS_EMA3']), 'CLS>EMA3'] = 0

# %% [markdown]
# # WEEKLY SELL

# %% [markdown]
# ## Weekly Joker EMA SELL CREATION

# %%
###JOKER SELL EMA###
J=int(values[17])


wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=J), 'CLS_EMAJ'] = wdb_mdb_ref.groupby(wdb_mdb_ref["Name"]).Close.transform(lambda c: c.ewm(span=J, adjust=False).mean())

    

wdb_mdb_ref.loc[(wdb_mdb_ref['#']<J), 'CLS>EMAJ'] = 0
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=J)&(wdb_mdb_ref['Close']>wdb_mdb_ref['CLS_EMAJ']), 'CLS>EMAJ'] = 1
wdb_mdb_ref.loc[(wdb_mdb_ref['#']>=J)&(wdb_mdb_ref['Close']<=wdb_mdb_ref['CLS_EMAJ']), 'CLS>EMAJ'] = 0

# %%
wdb_mdb_ref["SELL_EMA8"] = 0

wdb_mdb_ref["SELL_EMA3"] = 0

wdb_mdb_ref["Buy_Sell_EMA8"] = 0

wdb_mdb_ref["BUY_PRICE_EMA8_SELL"] = 0

wdb_mdb_ref["BUY_PRICE_EMA8_LINE"] = 0

wdb_mdb_ref["PRICE_EMA8_LINE_Profit"] = 0

wdb_mdb_ref["PRICE_EMA3_KICKS"] = 0

wdb_mdb_ref["TEMP_SELL_EMA3"] = 0

wdb_mdb_ref["TEMP_SELL_LINE_EMA3"] = 0

wdb_mdb_ref["BUY_SELL_EMA3"] = 0

wdb_mdb_ref["Symbol_Pos"] = 0

wdb_mdb_ref['Sell_VOL_EMA3']=0

wdb_mdb_ref['temp1_VOL_EMA3']=0

wdb_mdb_ref['temp2_VOL_EMA3']=0

# %% [markdown]
# ## Weekly SELL Below Joker EMA

# %%
######## SELL WHEN BELOW EMA8  ##########

if W_Sell_EMA8_exe==1:
    if W_Sell_EMA3_exe==0:
        if W_VOL_EMA3_exe==0:
        
            count = 0

            while count < x:

                #Sell_EMA8#

                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'SELL_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMAJ']==1),'SELL_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMAJ']==0),'SELL_EMA8'] = 1
    
                 #Sell Below EMA8
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Buy_Sell_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] == 1), 'Buy_Sell_EMA8'] = 1 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] == 1), 'Buy_Sell_EMA8'] = 0 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] != 1), 'Buy_Sell_EMA8'] = wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)

                 ### BUY / SELL / DECITION ###
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Symbol_Pos'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]== 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)== 0), 'Symbol_Pos'] = 'BUY'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]== 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)!= 0), 'Symbol_Pos'] = 'HOLD'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]!= 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)!= 1), 'Symbol_Pos'] = 'OUT'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]!= 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)== 1), 'Symbol_Pos'] = 'SELL'

                count = count + 1

# %% [markdown]
# ## Weekly SELL Below Joker EMA + EMA3

# %%
######## SELL WHEN BELOW EMA8 or if profit above X% SELL BELOW EMA3 ##########



if W_Sell_EMA8_exe==1:
    if W_Sell_EMA3_exe==1:
    
            

            count = 0

            while count < x:

                #Sell_EMA8#

                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'SELL_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8']==1),'SELL_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8']==0),'SELL_EMA8'] = 1
    
                #Sell_EMA3#

                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'SELL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA3']==1),'SELL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA3']==0),'SELL_EMA3'] = 1

                #Sell Below EMA8
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Buy_Sell_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] == 1), 'Buy_Sell_EMA8'] = 1 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] == 1), 'Buy_Sell_EMA8'] = 0 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] != 1), 'Buy_Sell_EMA8'] = wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)
            
            ##Activate Sell Below EMA8 when EMA3 Kicks in above x% ## SELL OPTION NUMBER 2##
 
                # step 1  - finding buy price using EMA8 sell Argument#
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'BUY_PRICE_EMA8_SELL'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)== 0), 'BUY_PRICE_EMA8_SELL'] = wdb_mdb_ref["Close"] 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)== 1), 'BUY_PRICE_EMA8_SELL'] = 0 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 0), 'BUY_PRICE_EMA8_SELL'] = 0 
            
                # step 2  - creating price line from EMA8 sell Argument#
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'BUY_PRICE_EMA8_LINE'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_SELL"]!= 0), 'BUY_PRICE_EMA8_LINE'] = wdb_mdb_ref["BUY_PRICE_EMA8_SELL"]
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_SELL"]== 0), 'BUY_PRICE_EMA8_LINE'] = wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 0), 'BUY_PRICE_EMA8_LINE'] = 0
    
                # step 3  - calculating profit on a price_line#
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'PRICE_EMA8_LINE_Profit'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"] != 0), 'PRICE_EMA8_LINE_Profit'] = ((wdb_mdb_ref["Close"]-wdb_mdb_ref["BUY_PRICE_EMA8_LINE"])/wdb_mdb_ref["BUY_PRICE_EMA8_LINE"])
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"] == 0), 'PRICE_EMA8_LINE_Profit'] = 0

                # step 4  - marking when profit is above x% to exit with EMA3#

                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'PRICE_EMA3_KICKS'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA8_LINE_Profit"] > W_EMA_Sell_Above_exe), 'PRICE_EMA3_KICKS'] = 1
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA8_LINE_Profit"] <= W_EMA_Sell_Above_exe)&(wdb_mdb_ref["PRICE_EMA3_KICKS"].shift(1)==1)&(wdb_mdb_ref["Buy_Sell_EMA8"]==1), 'PRICE_EMA3_KICKS'] = 1
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA8_LINE_Profit"] <= W_EMA_Sell_Above_exe)&(wdb_mdb_ref["PRICE_EMA3_KICKS"].shift(1)==1)&(wdb_mdb_ref["Buy_Sell_EMA8"]==0), 'PRICE_EMA3_KICKS'] = 0

                # step 5  - TEMP SELL EMA3
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'TEMP_SELL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA3_KICKS"] == 1)&(wdb_mdb_ref["SELL_EMA3"] == 1), 'TEMP_SELL_EMA3'] = "s"
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA3_KICKS"] != 1)&(wdb_mdb_ref["SELL_EMA3"] == 1), 'TEMP_SELL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA3_KICKS"] == 1)&(wdb_mdb_ref["SELL_EMA3"] != 1), 'TEMP_SELL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA3_KICKS"] != 1)&(wdb_mdb_ref["SELL_EMA3"] != 1), 'TEMP_SELL_EMA3'] = 0

    
                # step 6  - TEMP SELL_LINE_EMA3
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'TEMP_SELL_LINE_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA3_KICKS"] == 1)&(wdb_mdb_ref["TEMP_SELL_EMA3"] == "s"), 'TEMP_SELL_LINE_EMA3'] = "s"
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA3_KICKS"] == 1)&(wdb_mdb_ref["TEMP_SELL_EMA3"] != "s"), 'TEMP_SELL_LINE_EMA3'] = wdb_mdb_ref["TEMP_SELL_LINE_EMA3"].shift(1)
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA3_KICKS"] != 1), 'TEMP_SELL_LINE_EMA3'] = 0
    
                # step 7  - BUY/SELL EMA3

                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'BUY_SELL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 1)&(wdb_mdb_ref["TEMP_SELL_LINE_EMA3"] == 's'), 'BUY_SELL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 1)&(wdb_mdb_ref["TEMP_SELL_LINE_EMA3"] != 's'), 'BUY_SELL_EMA3'] = wdb_mdb_ref["Buy_Sell_EMA8"]
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 0)&(wdb_mdb_ref["TEMP_SELL_LINE_EMA3"] == 's'), 'BUY_SELL_EMA3'] = wdb_mdb_ref["Buy_Sell_EMA8"]
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"] == 0)&(wdb_mdb_ref["TEMP_SELL_LINE_EMA3"] != 's'), 'BUY_SELL_EMA3'] = wdb_mdb_ref["Buy_Sell_EMA8"]



                ### BUY / SELL / DECITION ###
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Symbol_Pos'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_SELL_EMA3"]== 1)&(wdb_mdb_ref["BUY_SELL_EMA3"].shift(1)== 0), 'Symbol_Pos'] = 'BUY'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_SELL_EMA3"]== 1)&(wdb_mdb_ref["BUY_SELL_EMA3"].shift(1)!= 0), 'Symbol_Pos'] = 'HOLD'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_SELL_EMA3"]!= 1)&(wdb_mdb_ref["BUY_SELL_EMA3"].shift(1)!= 1), 'Symbol_Pos'] = 'OUT'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_SELL_EMA3"]!= 1)&(wdb_mdb_ref["BUY_SELL_EMA3"].shift(1)== 1), 'Symbol_Pos'] = 'SELL'

    
                ### RESETING EMA 8 WHEN EMA3 SELL###
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'SELL_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'BUY_PRICE_EMA8_LINE'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'PRICE_EMA8_LINE_Profit'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'Buy_Sell_EMA8'] = 0
    
    
                count = count + 1

# %% [markdown]
# ## Weekly SELL Below Joker EMA + VOL ARG

# %%
######## SELL WHEN BELOW EMA8 AND VOL  BIGGER THEN AVG VOL BY X% ##########

if W_Sell_EMA8_exe==1:
    if W_Sell_EMA3_exe==0:
        if W_VOL_EMA3_exe==1:
        
            count = 0

            while count < x:

                #Sell_EMA8#

                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'SELL_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8']==1),'SELL_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['CLS>EMA8']==0),'SELL_EMA8'] = 1
    
                
                #Sell_VOL_EMA3#
                
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Sell_VOL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['Volume']*(1+VOL_EMA3_Sell_Above)>=wdb_mdb_ref['Vol_EMA3']), 'Sell_VOL_EMA3'] = 1
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['Volume']*(1+VOL_EMA3_Sell_Above)<wdb_mdb_ref['Vol_EMA3']), 'Sell_VOL_EMA3'] = 0


                #Sell Below EMA8 & SELL VOL EMA3#
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Buy_Sell_EMA8'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] == 1), 'Buy_Sell_EMA8'] = 1 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] == 1)&(wdb_mdb_ref["Sell_VOL_EMA3"] == 1), 'Buy_Sell_EMA8'] = 0 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] != 1)&(wdb_mdb_ref["Sell_VOL_EMA3"] == 1), 'Buy_Sell_EMA8'] = wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] == 1)&(wdb_mdb_ref["Sell_VOL_EMA3"] != 1), 'Buy_Sell_EMA8'] = wdb_mdb_ref["Buy_Sell_EMA8"].shift(1) 
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Temp_BUY"] != 1)&(wdb_mdb_ref["SELL_EMA8"] != 1)&(wdb_mdb_ref["Sell_VOL_EMA3"] != 1), 'Buy_Sell_EMA8'] = wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)
                

                 ### BUY / SELL / DECITION ###
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Symbol_Pos'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]== 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)== 0), 'Symbol_Pos'] = 'BUY'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]== 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)!= 0), 'Symbol_Pos'] = 'HOLD'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]!= 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)!= 1), 'Symbol_Pos'] = 'OUT'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Buy_Sell_EMA8"]!= 1)&(wdb_mdb_ref["Buy_Sell_EMA8"].shift(1)== 1), 'Symbol_Pos'] = 'SELL'



                count = count + 1

# %% [markdown]
# ## Weekly SELL Below Joker EMA + EMA3 + VOL ARG

# %%
######## SELL WHEN BELOW EMA8 or if profit above X% SELL BELOW EMA3 AND VOL BIGGER THEN AVG VOL BY X%##########

if W_Sell_EMA8_exe==1:
    if W_Sell_EMA3_exe==1:
        if W_VOL_EMA3_exe==1:
            
            wdb_mdb_ref["Symbol_Pos"]=""

            count = 0

            while count < x:

                #Sell_VOL_EMA3#
                
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Sell_VOL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['Volume']*(1+W_VOL_EMA3_Sell_Above)>=wdb_mdb_ref['Vol_EMA3']), 'Sell_VOL_EMA3'] = 1
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['Volume']*(1+W_VOL_EMA3_Sell_Above)<wdb_mdb_ref['Vol_EMA3']), 'Sell_VOL_EMA3'] = 0
                
                 #temp1_VOL_EMA3#
                
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'temp1_VOL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['BUY_SELL_EMA3']==0)&(wdb_mdb_ref['Sell_VOL_EMA3']==1) & (wdb_mdb_ref['PRICE_EMA3_KICKS']==0) & (wdb_mdb_ref['CLS>EMA8']==0), 'temp1_VOL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['BUY_SELL_EMA3']==0)&(wdb_mdb_ref['Sell_VOL_EMA3']==1) & (wdb_mdb_ref['PRICE_EMA3_KICKS']==0) & (wdb_mdb_ref['CLS>EMA8']==1), 'temp1_VOL_EMA3'] = wdb_mdb_ref['temp1_VOL_EMA3'].shift(1)
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['BUY_SELL_EMA3']==0)&(wdb_mdb_ref['Sell_VOL_EMA3']==1) & (wdb_mdb_ref['PRICE_EMA3_KICKS']==1) & (wdb_mdb_ref['SELL_EMA3']==1), 'temp1_VOL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['BUY_SELL_EMA3']==0)&(wdb_mdb_ref['Sell_VOL_EMA3']==1) & (wdb_mdb_ref['PRICE_EMA3_KICKS']==1) & (wdb_mdb_ref['SELL_EMA3']==0), 'temp1_VOL_EMA3'] =  wdb_mdb_ref['temp1_VOL_EMA3'].shift(1)
                
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['BUY_SELL_EMA3']==0)&(wdb_mdb_ref['Sell_VOL_EMA3']==0) , 'temp1_VOL_EMA3'] = wdb_mdb_ref['temp1_VOL_EMA3'].shift(1)
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref['BUY_SELL_EMA3']==1) , 'temp1_VOL_EMA3'] = wdb_mdb_ref['BUY_SELL_EMA3']
                
                wdb_mdb_ref.loc[(wdb_mdb_ref['PRICE_EMA3_KICKS'] == 1), 'temp2_VOL_EMA3'] = "***"
                
                 ### BUY / SELL / DECITION ###
    
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'Symbol_Pos'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["temp1_VOL_EMA3"]== 1)&(wdb_mdb_ref["temp1_VOL_EMA3"].shift(1)== 0), 'Symbol_Pos'] = 'BUY'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["temp1_VOL_EMA3"]== 1)&(wdb_mdb_ref["temp1_VOL_EMA3"].shift(1)!= 0), 'Symbol_Pos'] = 'HOLD'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["temp1_VOL_EMA3"]!= 1)&(wdb_mdb_ref["temp1_VOL_EMA3"].shift(1)!= 1), 'Symbol_Pos'] = 'OUT'
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["temp1_VOL_EMA3"]!= 1)&(wdb_mdb_ref["temp1_VOL_EMA3"].shift(1)== 1), 'Symbol_Pos'] = 'SELL'
                
                ###Adding relevant rows to priceline###
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)!= 0)&(wdb_mdb_ref["Symbol_Pos"]!= "SELL"), 'BUY_PRICE_EMA8_LINE'] = wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)!= 0)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'BUY_PRICE_EMA8_LINE'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)!= 0)&(wdb_mdb_ref["Symbol_Pos"]== "OUT"), 'BUY_PRICE_EMA8_LINE'] = 0
                
                #### Calculating Profit ###   
                
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)!= 0)&(wdb_mdb_ref["Symbol_Pos"]!= "SELL"), 'PRICE_EMA8_LINE_Profit'] = ((wdb_mdb_ref["Close"]-wdb_mdb_ref["BUY_PRICE_EMA8_LINE"])/wdb_mdb_ref["BUY_PRICE_EMA8_LINE"])
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)!= 0)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'PRICE_EMA8_LINE_Profit'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["BUY_PRICE_EMA8_LINE"].shift(1)!= 0)&(wdb_mdb_ref["Symbol_Pos"]== "OUT"), 'PRICE_EMA8_LINE_Profit'] = 0

                #### priceline EMA3 Kick ###  
                
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] == 1), 'PRICE_EMA3_KICKS'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA8_LINE_Profit"] > W_EMA_Sell_Above_exe), 'PRICE_EMA3_KICKS'] = 1
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA8_LINE_Profit"] <= W_EMA_Sell_Above_exe)&(wdb_mdb_ref["PRICE_EMA3_KICKS"].shift(1)==1)&(wdb_mdb_ref["temp1_VOL_EMA3"]==1), 'PRICE_EMA3_KICKS'] = 1
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["PRICE_EMA8_LINE_Profit"] <= W_EMA_Sell_Above_exe)&(wdb_mdb_ref["PRICE_EMA3_KICKS"].shift(1)==1)&(wdb_mdb_ref["temp1_VOL_EMA3"]==0), 'PRICE_EMA3_KICKS'] = 0
                
                ### RESETING WHEN SELL###
          
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'BUY_PRICE_EMA8_LINE'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'PRICE_EMA8_LINE_Profit'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'temp1_VOL_EMA3'] = 0
                wdb_mdb_ref.loc[(wdb_mdb_ref['#'] != 1)&(wdb_mdb_ref["Symbol_Pos"]== "SELL"), 'SELL_EMA3'] = 0

                count = count + 1

# %% [markdown]
# # WEEKLY BUY & SELL TEST FILES

# %%
wdb_mdb_ref.to_csv(W_Buy_Sell_Path + 'Buy_Creteria.csv', columns=('#', 'Name','Date','Close','M_IN',
                                                                  'Vol_EMA3_ARG','Candle','MA_LINED','CLS>MA20',
                                                                  'CLS>EMA8','CLS>EMA3','MA20TOUCH','SEQ_UP/DOWN','UP_DW_TREND','2trdDWmark',
                                                                  'TrendCalc','UP_DW_TREND','Buy_Combined','BUY_Decision','Temp_BUY'),index=False)

# %%
 W_PANEL.to_csv(W_Buy_Sell_Path +'w_panel.csv',index=False)

# %%
wdb_mdb_ref.to_csv(W_Buy_Sell_Path + 'W_buy_sell.csv', columns=('#', 'Name','Date','Close','Symbol_Pos'),index=False)

# %%
wdb_mdb_ref.to_csv(W_Buy_Sell_Path + 'W_buy_sell_ema.csv', columns=('#', 'Name','Date','Close','Temp_BUY','CLS_EMA8','CLS>EMAJ','Symbol_Pos'),index=False)

# %%
#with pd.ExcelWriter(W_Buy_Sell_Path + "W_P_L_Analysis.xlsx") as writer:  # doctest: +SKIP
 #   wdb_mdb_ref.to_excel(writer,columns=('#', 'Name','Date','Close','Symbol_Pos'), sheet_name='w_buy_sell')
  #  W_PANEL.to_excel(writer, sheet_name='w_panel')
  #  wdb_mdb_ref.to_excel(writer,columns=('#', 'Name','Date','Close','M_IN','Candle','Vol_EMA3_ARG','MA_LINED','CLS>MA20','CLS>EMA8','MA20TOUCH','SEQ_UP/DOWN','UP_DW_TREND','Buy_Combined','BUY_Decision','Temp_BUY'), sheet_name='w_buy')

# %% [markdown]
# # EXPORTING WEEKLY DB FOR DAILY DB

# %%
wdb_mdb_ref.to_csv(BTC_Data_Folder+'Wdb_Ddb_Ref.csv', columns=('Ref','Symbol_Pos','Temp_BUY'),index=False)
